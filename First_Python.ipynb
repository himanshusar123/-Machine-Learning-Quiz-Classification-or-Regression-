# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshusar123/-Machine-Learning-Quiz-Classification-or-Regression-/blob/main/First_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
pip --version
# Out:
# pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)

# %%
print("Welcome to AI for Web")
# Out:
# Welcome to AI for Web

# %%
#Variable

name="John"

age=25

print(name)
# Out:
# John

# %%
#input
name=input("Enter your name")

print("Welcome",name)
# Out:
# Enter your nameHimanshu
# Welcome Himanshu

# %%
#AI example

keywords=["buy","price","discount"]

sentence=input("Enter text : ")

for word in keywords:
    if word in sentence.lower():
        print("Marketing Intent Detected")
        break
# Out:
# Enter text : I want to get discount
# Marketing Intent Detected

# %%
education=["course","training","college"]

shopping=["buy","discount","offer"]

text=input("Enter website description")

if any(word in text.lower() for word in education):
    print("Education Website")

elif any(word in text.lower() for word in shopping):
    print("Shopping Website")

else:
    print("General Website")
# Out:
# Enter website descriptionI want festive offer
# Shopping Website
