# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshusar123/-Machine-Learning-Quiz-Classification-or-Regression-/blob/main/Advance_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-dba3d889-d910-48ce-ac32-60e270c73d23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dba3d889-d910-48ce-ac32-60e270c73d23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Advanced_HR_Attrition_EDA_Dataset.csv")

# %%
df.head()
# Out:
#    EmployeeID  Age              Department          JobRole  MonthlyIncome  \
# 0        1001   50                   Sales     HR Executive         132941
# 1        1002   36  Research & Development  Sales Executive          78351
# 2        1003   29                   Sales     HR Executive          86267
# 3        1004   42  Research & Development  Sales Executive         148133
# 4        1005   40                      HR     HR Executive          73354
#
#    YearsAtCompany  JobSatisfaction  WorkLifeBalance OverTime Attrition
# 0               3                4                1      Yes       Yes
# 1               8                4                2       No        No
# 2              14                4                1      Yes        No
# 3              18                3                3       No        No
# 4              15                2                3       No        No

# %%
df.tail()
# Out:
#     EmployeeID  Age              Department             JobRole  \
# 95        1096   58                   Sales        HR Executive
# 96        1097   56  Research & Development  Research Scientist
# 97        1098   43                      HR             Manager
# 98        1099   48                      HR        HR Executive
# 99        1100   56                   Sales        HR Executive
#
#     MonthlyIncome  YearsAtCompany  JobSatisfaction  WorkLifeBalance OverTime  \
# 95         110314              19                1                2       No
# 96         148007               1                1                3       No
# 97          51641               5                2                3      Yes
# 98          59584              13                4                2       No
# 99          57745               4                4                2       No
#
#    Attrition
# 95        No
# 96        No
# 97        No
# 98        No
# 99        No

# %%
df.shape
# Out:
# (100, 10)

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Department', 'JobRole', 'MonthlyIncome',
#        'YearsAtCompany', 'JobSatisfaction', 'WorkLifeBalance', 'OverTime',
#        'Attrition'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EmployeeID       100 non-null    int64
#  1   Age              100 non-null    int64
#  2   Department       100 non-null    object
#  3   JobRole          100 non-null    object
#  4   MonthlyIncome    100 non-null    int64
#  5   YearsAtCompany   100 non-null    int64
#  6   JobSatisfaction  100 non-null    int64
#  7   WorkLifeBalance  100 non-null    int64
#  8   OverTime         100 non-null    object
#  9   Attrition        100 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#         EmployeeID         Age  MonthlyIncome  YearsAtCompany  \
# count   100.000000  100.000000       100.0000      100.000000
# mean   1050.500000   40.060000     92182.8900        9.710000
# std      29.011492   10.688255     49147.2884        5.707155
# min    1001.000000   22.000000     25301.0000        1.000000
# 25%    1025.750000   30.000000     62823.0000        5.000000
# 50%    1050.500000   41.500000     82853.0000       10.000000
# 75%    1075.250000   48.000000    120183.0000       15.000000
# max    1100.000000   59.000000    350000.0000       19.000000
#
#        JobSatisfaction  WorkLifeBalance
# count       100.000000       100.000000
# mean          2.480000         2.390000
# std           1.210059         1.127212
# min           1.000000         1.000000
# 25%           1.000000         1.000000
# 50%           2.500000         2.000000
# 75%           4.000000         3.000000
# max           4.000000         4.000000

# %%
df.isnull().sum()
# Out:
# EmployeeID         0
# Age                0
# Department         0
# JobRole            0
# MonthlyIncome      0
# YearsAtCompany     0
# JobSatisfaction    0
# WorkLifeBalance    0
# OverTime           0
# Attrition          0
# dtype: int64

# %%
len(df)
# Out:
# 100

# %%
df["Department"].unique()
# Out:
# array(['Sales', 'Research & Development', 'HR'], dtype=object)

# %%
df["JobRole"].unique()
# Out:
# array(['HR Executive', 'Sales Executive', 'Research Scientist', 'Manager'],
#       dtype=object)

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     61
# Yes    39
# Name: count, dtype: int64

# %%
sorted(df["Age"].unique())
# Out:
# [np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(27),
#  np.int64(28),
#  np.int64(29),
#  np.int64(30),
#  np.int64(31),
#  np.int64(32),
#  np.int64(33),
#  np.int64(35),
#  np.int64(36),
#  np.int64(37),
#  np.int64(38),
#  np.int64(39),
#  np.int64(40),
#  np.int64(41),
#  np.int64(42),
#  np.int64(43),
#  np.int64(44),
#  np.int64(45),
#  np.int64(46),
#  np.int64(47),
#  np.int64(48),
#  np.int64(49),
#  np.int64(50),
#  np.int64(51),
#  np.int64(52),
#  np.int64(54),
#  np.int64(55),
#  np.int64(56),
#  np.int64(57),
#  np.int64(58),
#  np.int64(59)]

# %%
df["Age"].value_counts().sort_index()
# Out:
# Age
# 22    2
# 23    4
# 24    2
# 25    3
# 26    1
# 27    1
# 28    4
# 29    6
# 30    4
# 31    1
# 32    3
# 33    2
# 35    4
# 36    4
# 37    2
# 38    2
# 39    3
# 40    1
# 41    1
# 42    4
# 43    3
# 44    3
# 45    7
# 46    4
# 47    3
# 48    2
# 49    3
# 50    3
# 51    1
# 52    1
# 54    3
# 55    2
# 56    5
# 57    3
# 58    2
# 59    1
# Name: count, dtype: int64

# %%
df["JobRole"].unique()
# Out:
# array(['HR Executive', 'Sales Executive', 'Research Scientist', 'Manager'],
#       dtype=object)

# %%
df["Age_Group"] = pd.cut(
    df["Age"],
    bins=[20,30,40,50,60],
    labels=["21-30","31-40","41-50","51-60"]
)

df.head()
# Out:
#    EmployeeID  Age              Department          JobRole  MonthlyIncome  \
# 0        1001   50                   Sales     HR Executive         132941
# 1        1002   36  Research & Development  Sales Executive          78351
# 2        1003   29                   Sales     HR Executive          86267
# 3        1004   42  Research & Development  Sales Executive         148133
# 4        1005   40                      HR     HR Executive          73354
#
#    YearsAtCompany  JobSatisfaction  WorkLifeBalance OverTime Attrition  \
# 0               3                4                1      Yes       Yes
# 1               8                4                2       No        No
# 2              14                4                1      Yes        No
# 3              18                3                3       No        No
# 4              15                2                3       No        No
#
#   Age_Group
# 0     41-50
# 1     31-40
# 2     21-30
# 3     41-50
# 4     31-40

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     61
# Yes    39
# Name: count, dtype: int64

# %%
df["OverTime"].value_counts()
# Out:
# OverTime
# No     54
# Yes    46
# Name: count, dtype: int64

# %%
# 1. Data Profiling
# 2. Data Quality Check
# 3. Univariate Analysis
# 4. Bivariate Analysis
# 5. Outlier Analysis
# 6. Correlation Analysis
# 7. Business Insights & Recommendations
df["Age"].mean()
# Out:
# np.float64(40.06)

# %%
print("Average Age:", round(df["Age"].mean(), 2))
# Out:
# Average Age: 40.06

# %%
print("Highest Salary:", df["MonthlyIncome"].max())
# Out:
# Highest Salary: 350000

# %%
print("Average Tenure:", round(df["YearsAtCompany"].mean(), 2))
# Out:
# Average Tenure: 9.71

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# STAGE 3: UNIVARIATE ANALYSIS

# %%
plt.hist(df["Age"])

plt.title("Employee Age Distribution")

plt.show()

# %%
df["Age_Group"] = pd.cut(
    df["Age"],
    bins=[20,30,40,50,60],
    labels=["21-30","31-40","41-50","51-60"]
)

# %%
# SALARY ANALYSIS
df["MonthlyIncome"].describe()
# Out:
# count       100.0000
# mean      92182.8900
# std       49147.2884
# min       25301.0000
# 25%       62823.0000
# 50%       82853.0000
# 75%      120183.0000
# max      350000.0000
# Name: MonthlyIncome, dtype: float64

# %%
plt.hist(df["MonthlyIncome"])

plt.title("Salary Distribution")

plt.show()

# %%
# BIVARIATE ANALYSIS

# %%
# AGE VS ATTRITION

pd.crosstab(
    df["Age_Group"],
    df["Attrition"]
)
# Out:
# Attrition  No  Yes
# Age_Group
# 21-30      12   15
# 31-40      14    8
# 41-50      20   13
# 51-60      15    3

# %%
pd.crosstab(
    df["Age_Group"],
    df["Attrition"],
    normalize="index"
)*100
# Out:
# Attrition         No        Yes
# Age_Group
# 21-30      44.444444  55.555556
# 31-40      63.636364  36.363636
# 41-50      60.606061  39.393939
# 51-60      83.333333  16.666667

# %%
# OVERTIME VS ATTRITION
pd.crosstab(
    df["OverTime"],
    df["Attrition"]
)
# Out:
# Attrition  No  Yes
# OverTime
# No         45    9
# Yes        16   30

# %%
pd.crosstab(
    df["OverTime"],
    df["Attrition"],
    normalize="index"
)*100
# Out:
# Attrition         No        Yes
# OverTime
# No         83.333333  16.666667
# Yes        34.782609  65.217391

# %%
# DEPARTMENT VS ATTRITION

pd.crosstab(
    df["Department"],
    df["Attrition"]
)
# Out:
# Attrition               No  Yes
# Department
# HR                      16   13
# Research & Development  24   10
# Sales                   21   16

# %%
pd.crosstab(
    df["Department"],
    df["Attrition"],
    normalize="index"
)*100
# Out:
# Attrition                      No        Yes
# Department
# HR                      55.172414  44.827586
# Research & Development  70.588235  29.411765
# Sales                   56.756757  43.243243

# %%
# OUTLIER ANALYSIS

plt.boxplot(df["MonthlyIncome"])

plt.title("Salary Outlier Detection")

plt.show()

# %%
df.sort_values(
    by="MonthlyIncome",
    ascending=False
).head(10)
# Out:
#     EmployeeID  Age              Department             JobRole  \
# 15        1016   51  Research & Development             Manager
# 5         1006   44  Research & Development  Research Scientist
# 68        1069   46                   Sales             Manager
# 87        1088   28  Research & Development        HR Executive
# 3         1004   42  Research & Development     Sales Executive
# 96        1097   56  Research & Development  Research Scientist
# 23        1024   48                   Sales        HR Executive
# 13        1014   23  Research & Development     Sales Executive
# 94        1095   45                   Sales        HR Executive
# 84        1085   54                   Sales  Research Scientist
#
#     MonthlyIncome  YearsAtCompany  JobSatisfaction  WorkLifeBalance OverTime  \
# 15         350000              10                4                2       No
# 5          300000               2                1                1       No
# ...

# %%
# CORRELATION ANALYSIS
df.corr(numeric_only=True)
# Out:
#                  EmployeeID       Age  MonthlyIncome  YearsAtCompany  \
# EmployeeID         1.000000  0.095999      -0.156845       -0.065856
# Age                0.095999  1.000000       0.140202       -0.121422
# MonthlyIncome     -0.156845  0.140202       1.000000       -0.087292
# YearsAtCompany    -0.065856 -0.121422      -0.087292        1.000000
# JobSatisfaction   -0.147894  0.020400      -0.127743       -0.011818
# WorkLifeBalance   -0.024247 -0.126884       0.010664        0.027179
#
#                  JobSatisfaction  WorkLifeBalance
# EmployeeID             -0.147894        -0.024247
# Age                     0.020400        -0.126884
# MonthlyIncome          -0.127743         0.010664
# YearsAtCompany         -0.011818         0.027179
# JobSatisfaction         1.000000         0.039101
# WorkLifeBalance         0.039101         1.000000

# %%
import seaborn as sns

plt.figure(figsize=(8,6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True
)

plt.show()
