# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshusar123/-Machine-Learning-Quiz-Classification-or-Regression-/blob/main/Day_7__USS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# %%
from google.colab import files
uploaded = files.upload()

df = pd.read_csv("Customer_Loan_Approval_Dataset.csv")

df.head()
# Out:
#      <input type="file" id="files-24cbea7f-affb-4ed1-8cea-5219675ebb10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24cbea7f-affb-4ed1-8cea-5219675ebb10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.info()

df.describe()

df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Application_ID     150 non-null    object
#  1   Gender             150 non-null    object
#  2   Married            150 non-null    object
#  3   Education          150 non-null    object
#  4   Self_Employed      150 non-null    object
#  5   ApplicantIncome    150 non-null    int64
#  6   CoapplicantIncome  150 non-null    int64
#  7   LoanAmount         150 non-null    int64
#  8   Loan_Amount_Term   150 non-null    int64
#  9   Credit_History     150 non-null    int64
#  10  Property_Area      150 non-null    object
#  11  Loan_Status        150 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 14.2+ KB
# Application_ID       0
# Gender               0
# Married              0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# ...

# %%
df = pd.get_dummies(
    df,
    columns=[
        "Gender",
        "Married",
        "Education",
        "Self_Employed",
        "Property_Area"
    ],
    drop_first=True
)

df.head()
# Out:
#   Application_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0         APP001             5657               1143         238
# 1         APP002             5582               1905         179
# 2         APP003            11654               2278         257
# 3         APP004             5527               2757          76
# 4         APP005             9527               4392          81
#
#    Loan_Amount_Term  Credit_History Loan_Status  Gender_Male  Married_Yes  \
# 0               180               0    Rejected         True         True
# 1               360               0    Approved        False         True
# 2               180               1    Approved         True        False
# 3               180               1    Approved        False        False
# 4               240               0    Rejected        False        False
#
#    Education_Not Graduate  Self_Employed_Yes  Property_Area_Semiurban  \
# ...

# %%
df["Loan_Status"] = df["Loan_Status"].map({
    "Rejected":0,
    "Approved":1
})

# %%
X = df.drop(columns=["Application_ID","Loan_Status"])

y = df["Loan_Status"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
model = LogisticRegression(max_iter=1000)

model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy :", accuracy)
# Out:
# Accuracy : 1.0

# %%
cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[ 1  0]
#  [ 0 29]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00        29
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
comparison = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred
})

comparison.head(10)
# Out:
#    Actual  Predicted
# 0       1          1
# 1       0          0
# 2       1          1
# 3       1          1
# 4       1          1
# 5       1          1
# 6       1          1
# 7       1          1
# 8       1          1
# 9       1          1

# %%
print(X.columns)
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Gender_Male', 'Married_Yes',
#        'Education_Not Graduate', 'Self_Employed_Yes',
#        'Property_Area_Semiurban', 'Property_Area_Urban'],
#       dtype='object')

# %%
new_customer = pd.DataFrame({
    "ApplicantIncome":[2000],
    "CoapplicantIncome":[500],
    "LoanAmount":[1500],
    "Loan_Amount_Term":[360],
    "Credit_History":[1],
    "Gender_Male":[1],
    "Married_Yes":[1],
    "Education_Not Graduate":[0],
    "Self_Employed_Yes":[0],
    "Property_Area_Semiurban":[1],
    "Property_Area_Urban":[0]
})

prediction = model.predict(new_customer)

if prediction[0] == 1:
    print("Loan Approved")
else:
    print("Loan Rejected")
# Out:
# Loan Rejected
