# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshusar123/-Machine-Learning-Quiz-Classification-or-Regression-/blob/main/Day_2_Harbinger_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

print("=" * 60)
print("RetailMax HR Automation System")
print("=" * 60)

current_path = os.getcwd()

print(f"Current Working Directory : {current_path}")
# Out:
# ============================================================
# RetailMax HR Automation System
# ============================================================
# Current Working Directory : /content

# %%
filename = "employees.csv"

if os.path.exists(filename):
    print("Employee database found.")
else:
    print("Employee database NOT found.")
# Out:
# Employee database found.

# %%
full_path = os.path.abspath(filename)

print(f"\nEmployee Database Path")
print(full_path)
# Out:
# Employee Database Path
# /content/employees.csv

# %%
import csv

with open(filename, "r") as file:

    reader = csv.reader(file)

    rows = list(reader)

employee_count = len(rows) - 1      # Ignore Header

print(f"\nExisting Employees : {employee_count}")
# Out:
# Existing Employees : 49

# %%
# Display All Employees
import csv

print("=" * 70)
print("RetailMax HR Employee Database")
print("=" * 70)

with open(filename, "r") as file:

    reader = csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ======================================================================
# RetailMax HR Employee Database
# ======================================================================
# ['1001', 'Rahul Sharma', 'Finance', '65000']
# ['1002', 'Priya Verma', 'HR', '55000']
# ['1003', 'Amit Kumar', 'IT', '72000']
# ['1004', 'Neha Gupta', 'Marketing', '58000']
# ['1005', 'Rohit Mehta', 'Finance', '68000']
# ['1006', 'Anjali Singh', 'HR', '60000']
# ['1007', 'Vikas Arora', 'IT', '85000']
# ['1008', 'Pooja Malhotra', 'Sales', '52000']
# ['1009', 'Karan Khanna', 'Operations', '62000']
# ['1010', 'Simran Kaur', 'Finance', '70000']
# ['1011', 'Arjun Kapoor', 'IT', '91000']
# ['1012', 'Deepika Jain', 'HR', '57000']
# ['1013', 'Manish Agarwal', 'Marketing', '63000']
# ['1014', 'Ritika Sharma', 'Sales', '54000']
# ['1015', 'Sachin Bansal', 'Operations', '67000']
# ['1016', 'Nitin Verma', 'Finance', '76000']
# ['1017', 'Sonia Arora', 'IT', '89000']
# ['1018', 'Varun Gupta', 'Sales', '56000']
# ['1019', 'Megha Kapoor', 'HR', '61000']
# ['1020', 'Abhishek Singh', 'Marketing', '65000']
# ['1021', 'Kunal Mehra', 'Finance', '71000']
# ['1022', 'Shreya Nanda', 'IT', '94000']
# ['1023', 'Tarun Sethi', 'Operations', '69000']
# ['1024', 'Isha Bhatia', 'HR', '59000']
# ['1025', 'Rajat Malhotra', 'Sales', '61000']
# ['1026', 'Aman Khurana', 'Finance', '78000']
# ['1027', 'Divya Chawla', 'Marketing', '64000']
# ['1028', 'Gaurav Saini', 'IT', '88000']
# ['1029', 'Nidhi Saxena', 'HR', '62000']
# ['1030', 'Harsh Vardhan', 'Operations', '70000']
# ['1031', 'Yash Sharma', 'Finance', '81000']
# ['1032', 'Komal Arora', 'Sales', '57000']
# ['1033', 'Mohit Jain', 'Marketing', '66000']
# ['1034', 'Sneha Kapoor', 'IT', '97000']
# ['1035', 'Rakesh Yadav', 'Operations', '72000']
# ['1036', 'Pallavi Sharma', 'HR', '63000']
# ['1037', 'Ankit Gupta', 'Finance', '79000']
# ['1038', 'Rhea Mehta', 'Sales', '59000']
# ['1039', 'Sumit Verma', 'IT', '93000']
# ['1040', 'Kriti Bansal', 'Marketing', '68000']
# ['1041', 'Ayush Goel', 'Operations', '71000']
# ['1042', 'Sakshi Gupta', 'Finance', '82000']
# ['1043', 'Hemant Sharma', 'IT', '96000']
# ['1044', 'Muskan Arora', 'HR', '65000']
# ['1045', 'Aditya Malhotra', 'Sales', '62000']
# ['1046', 'Bhavna Sethi', 'Marketing', '69000']
# ['1047', 'Naveen Khanna', 'Finance', '84000']
# ['1048', 'Tanya Kapoor', 'IT', '99000']
# ['1049', 'Prashant Singh', 'Operations', '73000']
# ['1050', 'Ruchi Jain', 'HR', '67000']

# %%
import csv

with open(filename, "r") as file:

    reader = csv.reader(file)

    print("-"*75)
    print(f"{'ID':<10}{'Name':<25}{'Department':<20}{'Salary':>10}")
    print("-"*75)

    for row in reader:

        print(f"{row[0]:<10}{row[1]:<25}{row[2]:<20}{row[3]:>10}")
# Out:
# ---------------------------------------------------------------------------
# ID        Name                     Department              Salary
# ---------------------------------------------------------------------------
# 1001      Rahul Sharma             Finance                  65000
# 1002      Priya Verma              HR                       55000
# 1003      Amit Kumar               IT                       72000
# 1004      Neha Gupta               Marketing                58000
# 1005      Rohit Mehta              Finance                  68000
# 1006      Anjali Singh             HR                       60000
# 1007      Vikas Arora              IT                       85000
# 1008      Pooja Malhotra           Sales                    52000
# 1009      Karan Khanna             Operations               62000
# 1010      Simran Kaur              Finance                  70000
# 1011      Arjun Kapoor             IT                       91000
# 1012      Deepika Jain             HR                       57000
# 1013      Manish Agarwal           Marketing                63000
# 1014      Ritika Sharma            Sales                    54000
# 1015      Sachin Bansal            Operations               67000
# 1016      Nitin Verma              Finance                  76000
# 1017      Sonia Arora              IT                       89000
# 1018      Varun Gupta              Sales                    56000
# 1019      Megha Kapoor             HR                       61000
# 1020      Abhishek Singh           Marketing                65000
# 1021      Kunal Mehra              Finance                  71000
# 1022      Shreya Nanda             IT                       94000
# 1023      Tarun Sethi              Operations               69000
# 1024      Isha Bhatia              HR                       59000
# 1025      Rajat Malhotra           Sales                    61000
# 1026      Aman Khurana             Finance                  78000
# 1027      Divya Chawla             Marketing                64000
# 1028      Gaurav Saini             IT                       88000
# 1029      Nidhi Saxena             HR                       62000
# 1030      Harsh Vardhan            Operations               70000
# 1031      Yash Sharma              Finance                  81000
# 1032      Komal Arora              Sales                    57000
# 1033      Mohit Jain               Marketing                66000
# 1034      Sneha Kapoor             IT                       97000
# 1035      Rakesh Yadav             Operations               72000
# 1036      Pallavi Sharma           HR                       63000
# 1037      Ankit Gupta              Finance                  79000
# 1038      Rhea Mehta               Sales                    59000
# 1039      Sumit Verma              IT                       93000
# 1040      Kriti Bansal             Marketing                68000
# 1041      Ayush Goel               Operations               71000
# 1042      Sakshi Gupta             Finance                  82000
# 1043      Hemant Sharma            IT                       96000
# 1044      Muskan Arora             HR                       65000
# 1045      Aditya Malhotra          Sales                    62000
# 1046      Bhavna Sethi             Marketing                69000
# 1047      Naveen Khanna            Finance                  84000
# 1048      Tanya Kapoor             IT                       99000
# 1049      Prashant Singh           Operations               73000
# 1050      Ruchi Jain               HR                       67000

# %%
# Searching employee by employee_id
search_id = input("Enter Employee ID : ")

found = False

with open(filename, "r") as file:

    reader = csv.reader(file)

    for row in reader:

        if row[0] == search_id:

            print("\nEmployee Found")

            print("-"*40)

            print("ID :", row[0])
            print("Name :", row[1])
            print("Department :", row[2])
            print("Salary :", row[3])

            found = True

            break

if not found:

    print("Employee Not Found")
# Out:
# Enter Employee ID : 1048
#
# Employee Found
# ----------------------------------------
# ID : 1048
# Name : Tanya Kapoor
# Department : IT
# Salary : 99000

# %%
# Search employees by Department

department = input("Enter Department : ")

with open(filename,"r") as file:

    reader = csv.reader(file)

    print()

    print("Employees in", department)

    print("-"*50)

    for row in reader:

        if row[2].lower()==department.lower():

            print(row)
# Out:
# Enter Department : IT
#
# Employees in IT
# --------------------------------------------------
# ['1003', 'Amit Kumar', 'IT', '72000']
# ['1007', 'Vikas Arora', 'IT', '85000']
# ['1011', 'Arjun Kapoor', 'IT', '91000']
# ['1017', 'Sonia Arora', 'IT', '89000']
# ['1022', 'Shreya Nanda', 'IT', '94000']
# ['1028', 'Gaurav Saini', 'IT', '88000']
# ['1034', 'Sneha Kapoor', 'IT', '97000']
# ['1039', 'Sumit Verma', 'IT', '93000']
# ['1043', 'Hemant Sharma', 'IT', '96000']
# ['1048', 'Tanya Kapoor', 'IT', '99000']

# %%
# Manager Needs report

import csv

total_salary = 0
employee_count = 0

with open(filename,"r") as file:

    reader = csv.reader(file)

    for row in reader:

        total_salary += int(row[3])

        employee_count += 1

print("Average Salary :", total_salary/employee_count)
# Out:
# Average Salary : 70900.0

# %%
# Deleting employee

# %%
# Transferring Employee
